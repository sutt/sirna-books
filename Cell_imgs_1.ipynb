# %%
import os, sys
import numpy as np
from matplotlib import pyplot as plt

# %%
sys.path.append('libs/rxrx1-utils/')
import rxrx

# %%
import skimage

# %%
all_imgs = os.listdir('sample_imgs')
d19_imgs = [e for e in all_imgs if 'D19' in e]

# %%
rand_fn = np.random.choice(d19_imgs)
print(rand_fn)
rand_img = skimage.io.imread(os.path.join('sample_imgs', rand_fn))
print(type(rand_img), rand_img.shape)
plt.imshow(rand_img)
# Out:
# D19_s2_w4.png
# <class 'imageio.core.util.Array'> (512, 512)

# %% [markdown]
# ##### What is the effect of cmap on this image? Dark blue to yellow?

# %%
rand_img.min(), rand_img.max()
# Out:
# (0, 59)

# %%
#is the max 2**8? or something else?

# %%
2 ** 8
# Out:
# 256

# %%
rand_img[:4,:4]
# Out:
# Array([[3, 2, 1, 1],
#        [3, 2, 1, 1],
#        [4, 3, 2, 1],
#        [4, 3, 2, 2]], dtype=uint8)

# %%
#graymap shows more diappointing 
plt.figure(figsize=(8,8))
plt.imshow(rand_img, cmap='gray')

# %%
[e for e in range(1,rand_img.shape[0]) if rand_img.shape[0] % e == 0]
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256]

# %%
flat_rand_img = rand_img.flatten()

# %%
plt.hist(flat_rand_img);

# %%
rand_img.

# %%
rand_img

# %%
import PIL

# %%
from PIL import Image

# %%
Image
