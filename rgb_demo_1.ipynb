# %%
import os, sys, copy
import numpy as np 
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

from utils.dataloader import DataLoader
from utils.imgplots import plot_two_imgs_by_channel
from utils.rxrxw import img_fns_to_rgb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### This books is demo work for RGB composite images

# %%
dc = DataLoader()

# %%
# using local directory of sample_imgs/exp1/Plate1/D19 (for site1+2)
ida_dummy = {'experiment':'exp1', 'plate': 1, 'well': 'D19'}

# %%
idb = dc.ida_to_idb(ida_dummy, site=1)

# %%
idcs = dc.idb_to_idcs(idb)

# %%
fns = dc.idcs_to_fns(idcs)

# %%
rgb_img = img_fns_to_rgb(fns)

# %%
plt.imshow(rgb_img)
